# %% [markdown]
# # Entrenamiento 1: Clustering de Jugadores del Fifa
#
# <b>Contexto</b>
#
# Este conjunto de datos contiene los datos de los jugadores del juego [FIFA 2018](https://www.kaggle.com/thec03u5/fifa-18-demo-player-dataset).
#
# <b>Contenido</b>
#
#
# * Todos los jugadores que aparecen en FIFA 18
# * Más de 70 atributos
# * Imágenes de jugadores y banderas
# * Datos de la posición de juego
# * Atributos basados en datos reales del juego FIFA 18 de EA
# * Los atributos incluyen todas las estadísticas de estilo de los jugadores como Regate, Agresión, Habilidades de GK, etc.
# * Datos personales del jugador como nacionalidad, foto, club, edad, salario, sueldo, etc.
#
# <b>El objetivo</b> de esta práctica es ver si hay alguna estructura de clusters en los datos y luego inferir qué criterio es el que mejor los agrupa.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Fifa_players.csv',low_memory=False)

# %%
df.head()
# Out:
#    Unnamed: 0               Name  Age  \
# 0           0  Cristiano Ronaldo   32
# 1           1           L. Messi   30
# 2           2             Neymar   25
# 3           3          L. Suárez   30
# 4           4           M. Neuer   31
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1  https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2  https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# 3  https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
# 4  https://cdn.sofifa.org/48/18/players/167495.png     Germany
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/38.png       94         94
# 1  https://cdn.sofifa.org/flags/52.png       93         93
# 2  https://cdn.sofifa.org/flags/54.png       92         94
# 3  https://cdn.sofifa.org/flags/60.png       92         92
# ...

# %% [markdown]
# # Data cleaning y feature engineering
#
# Utilizen las herramientas aprendidas para hacer una limpieza de datos y una construcción de nuevas si es necesario.

# %% [markdown]
# # Clustering
#
#
# * Implementen un algoritmo de KMeans variando el número de clusters en un rango que les suene razonable.
#
# <b>¿Qué hay que hacer antes con los datos?</b>
#
#
# * Grafiquen la inercia (suma de distancias cuadráticas a los centroides) en función de k. Esta medida queda almacenada en la propiedad 'inertia_' del objeto KMeans una vez entrenado.
#
# * Siguiendo la regla del codo, hay un valor de k preferencial?
#
# * Pueden otras métricas ayudarnos a entender el problema?

# %% [markdown]
# ## Composición de los clusters
#
# Veamos cómo están compuestos los clusters.
#
# * Hagan algunos box plots para cada cluster mostrando la información que les parezca relevante.

# %% [markdown]
# ## Visualización en un espacio de dimensionalidad reducida
#
# * Reduzcamos la dimensionalidad del dataset usando PCA y conservando dos componentes principales.
#
# * Grafiquemos con un scatterplot los k clusters que selecionamos en este espacio reducido.
